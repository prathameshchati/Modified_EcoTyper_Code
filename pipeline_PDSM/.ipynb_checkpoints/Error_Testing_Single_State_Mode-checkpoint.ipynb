# %% [markdown]
# ### Ecotype Recovery

# %%
suppressPackageStartupMessages({
library(cluster)
library(ggplot2)
library(viridis)
source("lib/misc.R")
source("lib/heatmaps.R")
source("lib/read_clinical.R")
})

# %%
# args = commandArgs(T) 
# dataset = args[1]
# fractions = args[2]
# test_dataset = args[3]
# top_cols = args[4:length(args)]

#### NEW ARGUMENTS ADDED

keyDir = "Test_12_Complete_Peng_Discovered_States_Ecotype_Discovery_PDSM_Updated_Recovery_SSM_Run_090222"
inputDir = "Test_12_Complete_Peng_Discovered_States_Ecotype_Discovery_PDSM_Updated_Recovery_SSM_Run_090222/TCGA_Recovery_090222/Inputs"
outputDir = "Test_12_Complete_Peng_Discovered_States_Ecotype_Discovery_PDSM_Updated_Recovery_SSM_Run_090222/TCGA_Recovery_090222"
priorDisc = "/duo4/users/pchati/EcoTyper_Updated/ecotyper/EcoTyper/Discovery_scRNA_EcoTyper_Downsized_Peng_082922/Cell_type_specific_genes/Cell_States/discovery"
priorRank = "/duo4/users/pchati/EcoTyper_Updated/ecotyper/EcoTyper/Discovery_scRNA_EcoTyper_Downsized_Peng_082922/Cell_type_specific_genes/Analysis/rank_selection"
singleStateCellTypes = c("Mast", "Plasma", "Stellate", "Endothelial", "Acinar", "Normal_Epithelial", "B_cell")
# top_cols = args[7]

# %%
# if(is.na(top_cols[1]))
# {
# 	top_cols = "Ecotype"
# }
# top_cols = unique(c(top_cols, "Ecotype"))
top_cols = "Ecotype"

# cat(paste0("Running ecotype recovery...\n"))

# key_dir = file.path("../EcoTyper", dataset, fractions, "Analysis", "rank_selection")
key_dir = file.path("/duo4/users/pchati/ecotyper/Generate_Cell_State_Abundances_Predefined_States_Test_Outputs", keyDir)

# states_dir = file.path("../EcoTyper", dataset, fractions, "Cell_States", "recovery", test_dataset)
# states_dir = file.path("/duo4/users/pchati/ecotyper/Generate_Cell_State_Abundances_Predefined_States_Test_Outputs", "Test_8_Peng_Discovered_States_EcoTyper_PDSM_Run_083022", "TCGA_Recovery_090122")
states_dir = file.path("/duo4/users/pchati/ecotyper/Generate_Cell_State_Abundances_Predefined_States_Test_Outputs", outputDir)


# inpput_dir = file.path("../EcoTyper", dataset, fractions, "Ecotypes", "discovery")
input_dir = file.path("/duo4/users/pchati/ecotyper/Generate_Cell_State_Abundances_Predefined_States_Test_Outputs", keyDir, "Ecotypes")

# output_dir = file.path("../EcoTyper", dataset, fractions, "Ecotypes", "recovery", test_dataset)
output_dir = file.path("/duo4/users/pchati/ecotyper/Generate_Cell_State_Abundances_Predefined_States_Test_Outputs", outputDir, "Ecotypes") 

dir.create(output_dir, recursive = T, showWarning = F) 

key = read.delim(file.path(key_dir, "rank_data.txt"))

priorKey = read.delim(file.path(priorRank, "rank_data.txt"))


# ecotypes = read.delim(file.path(inpput_dir, 'ecotypes.txt'), sep = '\t')
ecotypes = read.delim(file.path(input_dir, 'ecotypes.txt'), sep = '\t')

ecotypes$Ecotype = ecotype_to_factor(ecotypes$Ecotype)
ecotypes = ecotypes[order(ecotypes$Ecotype),]

all_H = NULL
all_classes_filt = NULL

# %%
# test_cell_types = c("Mast")

# %%
for(cell_type in key[,1])
# for (cell_type in test_cell_types)
{	
    
    
#     if(cell_type %in% singleStateCellTypes) {
    
#         n_clusters = priorKey[priorKey[,1] == cell_type,2]
#         states_dir = file.path(priorDisc, cell_type, n_clusters)
        
# #         n_clusters = key[key[,1] == cell_type,2]
# #         states_dir = file.path("/duo4/users/pchati/ecotyper/Generate_Cell_State_Abundances_Predefined_States_Test_Outputs", outputDir, cell_type)

#         print(cell_type) 

#     } else {
#         n_clusters = key[key[,1] == cell_type,2]
#         states_dir = file.path("/duo4/users/pchati/ecotyper/Generate_Cell_State_Abundances_Predefined_States_Test_Outputs", outputDir, cell_type)
#     }
    
    states_dir = file.path("/duo4/users/pchati/ecotyper/Generate_Cell_State_Abundances_Predefined_States_Test_Outputs", outputDir, cell_type)
	#print(cell_type) 

#     n_clusters = key[key[,1] == cell_type,2]
    
# 	classes = read.delim(file.path(states_dir, cell_type, n_clusters, 'state_abundances.txt'))
#     classes = read.delim(file.path(states_dir, cell_type, 'state_abundances.txt'))
    classes = read.delim(file.path(states_dir, 'state_abundances.txt'))

	rownames(classes) = paste0(cell_type, "_", rownames(classes))
	all_H = rbind(all_H, classes)

# 	classes = read.delim(file.path(states_dir, cell_type, n_clusters, 'state_assignment.txt'))
#     classes = read.delim(file.path(states_dir, cell_type, 'state_assignment.txt'))
    classes = read.delim(file.path(states_dir, 'state_assignment.txt'))

    
	clusters = ecotypes[ecotypes$CellType == cell_type,] 
	classes = classes[classes$State %in% clusters$State,]
	classes = classes[,c("ID", "State")]
	colnames(classes) = c('ID', cell_type)

	if(is.null(all_classes_filt))
	{
		all_classes_filt = classes
	}else{
		all_classes_filt = merge(all_classes_filt, classes, by = 'ID', all = T)
	}	
}
# Out:
# [1] "Mast"
# [1] "Stellate"
# Error in rbind(deparse.level, ...): numbers of columns of arguments do not match
# Traceback:
#
# 1. rbind(all_H, classes)
# 2. rbind(deparse.level, ...)
# 3. stop("numbers of columns of arguments do not match")

# %%
all_H
# Out:
#                     X                    XT18         XT16        XN2
# Mast_1              S04                  0.4000000000 0.500000000 0.000000000
# Mast_2              S01                  0.0000000000 0.250000000 0.000000000
# Mast_3              S02                  0.2000000000 0.250000000 0.000000000
# Mast_4              S03                  0.2000000000 0.000000000 0.000000000
# Mast_5              S05                  0.2000000000 0.000000000 0.000000000
# Stellate_1          S03                  0.1527777778 0.261904762 0.000000000
# Stellate_2          S02                  0.4166666667 0.142857143 0.000000000
# Stellate_3          S04                  0.1111111111 0.226190476 0.035714286
# Stellate_4          S01                  0.2638888889 0.190476190 0.035714286
# Stellate_5          S05                  0.0555555556 0.178571429 0.928571429
# Fibroblast_1        myCAF                0.3140495868 0.519668737 0.004237288
# Fibroblast_2        iCAF                 0.6859504132 0.480331263 0.995762712
# B_cell_1            S04                  1.0000000000 0.520000000 0.000000000
# B_cell_2            S03                  0.0000000000 0.120000000 0.000000000
# B_cell_3            S01                  0.0000000000 0.160000000 0.000000000
# B_cell_4            S02                  0.0000000000 0.200000000 0.000000000
# Malignant_1         Acinar               0.0003460208 0.126436782 0.888888889
# Malignant_2         Malignant_IC         0.0678200692 0.780332056 0.023035230
# Malignant_3         Normal_Epithelial    0.0065743945 0.024265645 0.088075881
# Malignant_4         Malignant_Classical  0.8608996540 0.005108557 0.000000000
# Malignant_5         Malignant_Cycling    0.0643598616 0.005108557 0.000000000
# Malignant_6         Malignant_Basal      0.0000000000 0.058748404 0.000000000
# Endothelial_1       S02                  0.0000000000 0.000000000 0.444444444
# Endothelial_2       S04                  0.7567567568 0.416666667 0.222222222
# Endothelial_3       S03                  0.2162162162 0.527777778 0.222222222
# Endothelial_4       S01                  0.0270270270 0.055555556 0.111111111
# Monocyte_DC_1                            0.0000000000 0.000000000 0.000000000
# Monocyte_DC_2       DC_LAMP3             0.0062500000 0.010600707 0.000000000
# Monocyte_DC_3       Noise                0.0968750000 0.004416961 0.012376238
# Monocyte_DC_4       TAM_FCN1             0.1125000000 0.540636042 0.000000000
# Monocyte_DC_5       pDC                  0.0000000000 0.007067138 0.000000000
# Monocyte_DC_6       DC                   0.0968750000 0.113957597 0.009900990
# Monocyte_DC_7       TAM_C1QC             0.2656250000 0.260600707 0.977722772
# Normal_Epithelial_3 0.352941176 0.00000000 0.000000000
# Plasma_1            0.333333333 0.00000000 0.333333333
# Plasma_2            0.166666667 0.00000000 0.000000000
# Plasma_3            0.083333333 0.00000000 0.000000000
# Plasma_4            0.000000000 0.33333333 0.000000000
# Plasma_5            0.416666667 0.33333333 0.333333333
# Plasma_6            0.000000000 0.33333333 0.333333333
# Acinar_1            0.000000000 0.00000000 0.000000000
# Acinar_2            0.500000000 0.00000000 0.000000000
# Acinar_3            0.500000000 0.00000000 0.000000000
# Acinar_4            0.000000000 0.00000000 0.000000000
# NK_T_cell_1         0.023121387 0.27916667 0.198895028
# NK_T_cell_2         0.757225434 0.59166667 0.541436464
# NK_T_cell_3         0.000000000 0.01250000 0.011049724
# NK_T_cell_4         0.011560694 0.02708333 0.058011050
# NK_T_cell_5         0.000000000 0.03333333 0.104972376
# NK_T_cell_6         0.208092486 0.05625000 0.085635359

# %%
all_H = all_H[match(ecotypes$ID, rownames(all_H)),]
# write.table(all_H, file.path(output_dir, "combined_state_abundances.txt"), sep = "\t")

# %%
all_H
# Out:
#       X  XT18 XT16 XN2 XT19 XT7 XT8 XT11 XT21 XT22 ⋯ XT14 XN11 XT12 XT15 XT5
# NA    NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.1  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.2  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.3  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.4  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.5  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.6  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.7  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.8  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.9  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.10 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.11 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.12 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.13 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.14 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.15 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.16 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.17 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.18 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.19 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.20 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.21 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.22 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.23 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
#       XT4 XN9 XN3 XT1 XT10
# NA    NA  NA  NA  NA  NA
# NA.1  NA  NA  NA  NA  NA
# NA.2  NA  NA  NA  NA  NA
# NA.3  NA  NA  NA  NA  NA
# NA.4  NA  NA  NA  NA  NA
# NA.5  NA  NA  NA  NA  NA
# NA.6  NA  NA  NA  NA  NA
# NA.7  NA  NA  NA  NA  NA
# NA.8  NA  NA  NA  NA  NA
# NA.9  NA  NA  NA  NA  NA
# NA.10 NA  NA  NA  NA  NA
# NA.11 NA  NA  NA  NA  NA
# NA.12 NA  NA  NA  NA  NA
# NA.13 NA  NA  NA  NA  NA
# NA.14 NA  NA  NA  NA  NA
# NA.15 NA  NA  NA  NA  NA
# NA.16 NA  NA  NA  NA  NA
# NA.17 NA  NA  NA  NA  NA
# NA.18 NA  NA  NA  NA  NA
# NA.19 NA  NA  NA  NA  NA
# NA.20 NA  NA  NA  NA  NA
# NA.21 NA  NA  NA  NA  NA
# NA.22 NA  NA  NA  NA  NA
# NA.23 NA  NA  NA  NA  NA

# %%
H = do.call(rbind, lapply(levels(ecotypes$Ecotype), function(clst){
	clst <<- clst
	#print(clst)
	inc <<- ecotypes[ecotypes$Ecotype == clst,]$ID
	apply(all_H[rownames(all_H) %in% inc,,drop = F], 2, mean)
}))
rownames(H) = levels(ecotypes$Ecotype)
#write.table(H, file.path(output_dir, "ecotype_abundance.txt"), sep = "\t")
H = apply(H, 2, function(x) x / sum(x))
write.table(H, file.path(output_dir, "ecotype_abundance.txt"), sep = "\t")

p_vals = do.call(rbind, lapply(levels(ecotypes$Ecotype), function(clst){
	clst <<- clst
	#print(clst)
	inc <<- ecotypes[ecotypes$Ecotype == clst,]$ID
	
	apply(all_H, 2, function(x){
		x <<- x
		err <<- F
		p <<- 1
		tryCatch({
			p <<- t.test(x[rownames(all_H) %in% inc], x[!(rownames(all_H) %in% inc)])$p.value
		}, error = function(x) err <<- T)
		p
	})
	
}))
# Out:
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(x):
# “argument is not numeric or logical: returning NA”

# %%
all_H
# Out:
#       X  XT18 XT16 XN2 XT19 XT7 XT8 XT11 XT21 XT22 ⋯ XT14 XN11 XT12 XT15 XT5
# NA    NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.1  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.2  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.3  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.4  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.5  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.6  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.7  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.8  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.9  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.10 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.11 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.12 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.13 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.14 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.15 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.16 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.17 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.18 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.19 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.20 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.21 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.22 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.23 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
#       XT4 XN9 XN3 XT1 XT10
# NA    NA  NA  NA  NA  NA
# NA.1  NA  NA  NA  NA  NA
# NA.2  NA  NA  NA  NA  NA
# NA.3  NA  NA  NA  NA  NA
# NA.4  NA  NA  NA  NA  NA
# NA.5  NA  NA  NA  NA  NA
# NA.6  NA  NA  NA  NA  NA
# NA.7  NA  NA  NA  NA  NA
# NA.8  NA  NA  NA  NA  NA
# NA.9  NA  NA  NA  NA  NA
# NA.10 NA  NA  NA  NA  NA
# NA.11 NA  NA  NA  NA  NA
# NA.12 NA  NA  NA  NA  NA
# NA.13 NA  NA  NA  NA  NA
# NA.14 NA  NA  NA  NA  NA
# NA.15 NA  NA  NA  NA  NA
# NA.16 NA  NA  NA  NA  NA
# NA.17 NA  NA  NA  NA  NA
# NA.18 NA  NA  NA  NA  NA
# NA.19 NA  NA  NA  NA  NA
# NA.20 NA  NA  NA  NA  NA
# NA.21 NA  NA  NA  NA  NA
# NA.22 NA  NA  NA  NA  NA
# NA.23 NA  NA  NA  NA  NA

# %%
rownames(p_vals) = levels(ecotypes$Ecotype)
write.table(p_vals, file.path(output_dir, "assignment_p_vals.txt"), sep = "\t")

assignment = as.data.frame(apply(H, 2, function(x) rownames(H)[which.max(x)]))

clinical = data.frame(ID = rownames(assignment), MaxEcotype = assignment[,1])
clinical$AssignmentP = sapply(1:ncol(H), function(i) {
	p_vals[which.max(H[,i]), i] 
	})
clinical$AssignmentQ = p.adjust(clinical$AssignmentP, method = "BH")

clinical$AssignedToEcotypeStates = clinical$ID %in% all_classes_filt$ID
clinical$Ecotype = ifelse((clinical$AssignmentQ < 0.25) & clinical$AssignedToEcotypeStates, as.character(clinical$MaxEcotype), "Unassigned")
clinical$Ecotype = factor(as.character(clinical$Ecotype), levels = c(levels(ecotypes$Ecotype), "Unassigned"))

# tmp = read_clinical(clinical$ID, dataset = test_dataset, dataset_type = "bulk")
tmp = read_clinical_bulk(clinical$ID, bulkInputDir = inputDir, dataset_type = "bulk")                                 

to_rem = colnames(tmp)[colnames(tmp) %in% colnames(clinical)]
to_rem = to_rem[to_rem != "ID"]
tmp = tmp[,!colnames(tmp) %in% to_rem, drop = F]
clinical = merge(clinical, tmp, by = "ID", all.x = T)

clinical = clinical[order(clinical$Ecotype),]

H = H[,match(clinical$ID, colnames(H))]
all_H = all_H[,match(clinical$ID, colnames(all_H))]
all_H = all_H[match(ecotypes$ID, rownames(all_H)),]

write.table(clinical, file.path(output_dir, "initial_ecotype_assignment.txt"), sep = "\t")

rownames(clinical) = clinical$ID
rownames(ecotypes) = ecotypes$ID

clinical_filt = clinical[clinical$Ecotype != "Unassigned",]
clinical_filt$Ecotype = factor(as.character(clinical_filt$Ecotype), levels = levels(ecotypes$Ecotype))
write.table(clinical_filt, file.path(output_dir, "ecotype_assignment.txt"), sep = "\t")

h <- heatmap_simple(all_H, top_annotation = clinical_filt, top_columns = top_cols, 
	left_annotation = ecotypes, left_columns = c("Ecotype", "CellType", "State"),
	column_split = ifelse(clinical$Ecotype == "Unassigned", "Unassigned", "Assigned"),
	width = unit(7, "in"), height = unit(4, "in"),
	legend_name = "State abundance",
	color_range = seq(0, quantile(as.matrix(all_H), .9), length.out = 8), color_palette = c("white", viridis(8)), raster_quality = 5)

pdf(file.path(output_dir, "heatmap_all_samples.pdf"), width = 12, height = 7)
draw(h, heatmap_legend_side = "bottom", annotation_legend_side = "bottom", merge_legends = T)	
tmp = dev.off()

small_H = as.matrix(all_H[,match(clinical_filt$ID, colnames(all_H))])

if(is.null(small_H) || nrow(small_H) == 0 || ncol(small_H) == 0)
{
	stop(paste("No samples were assigned to ecotypes!"))
}
# Out:
# Error in `$<-.data.frame`(`*tmp*`, AssignmentP, value = list(numeric(0), : replacement has 36 rows, data has 0
# Traceback:
#
# 1. `$<-`(`*tmp*`, AssignmentP, value = list(numeric(0), numeric(0),
#  .     numeric(0), numeric(0), numeric(0), numeric(0), numeric(0),
#  .     numeric(0), numeric(0), numeric(0), numeric(0), numeric(0),
#  .     numeric(0), numeric(0), numeric(0), numeric(0), numeric(0),
#  .     numeric(0), numeric(0), numeric(0), numeric(0), numeric(0),
#  .     numeric(0), numeric(0), numeric(0), numeric(0), numeric(0),
#  .     numeric(0), numeric(0), numeric(0), numeric(0), numeric(0),
#  .     numeric(0), numeric(0), numeric(0), numeric(0)))
# 2. `$<-.data.frame`(`*tmp*`, AssignmentP, value = list(numeric(0),
#  .     numeric(0), numeric(0), numeric(0), numeric(0), numeric(0),
#  .     numeric(0), numeric(0), numeric(0), numeric(0), numeric(0),
#  .     numeric(0), numeric(0), numeric(0), numeric(0), numeric(0),
#  .     numeric(0), numeric(0), numeric(0), numeric(0), numeric(0),
#  .     numeric(0), numeric(0), numeric(0), numeric(0), numeric(0),
#  .     numeric(0), numeric(0), numeric(0), numeric(0), numeric(0),
#  .     numeric(0), numeric(0), numeric(0), numeric(0), numeric(0)))
# 3. stop(sprintf(ngettext(N, "replacement has %d row, data has %d",
#  .     "replacement has %d rows, data has %d"), N, nrows), domain = NA)

# %%
h = heatmap_simple(small_H, top_annotation = clinical_filt, top_columns = top_cols, 
	left_annotation = ecotypes, left_columns = c("Ecotype", "CellType", "State"),
	width = unit(5, "in"), height = unit(3, "in"),
	legend_name = "State abundance",
	color_range = seq(0, quantile(as.matrix(all_H), .9), length.out = 8), color_palette = c("white", viridis(8)), raster_quality = 20)

pdf(file.path(output_dir, "heatmap_assigned_samples_viridis.pdf"), width = 8, height = 7)
draw(h, heatmap_legend_side = "bottom", annotation_legend_side = "bottom", merge_legends = T)	
#draw(h1, heatmap_legend_side = "bottom", annotation_legend_side = "bottom", merge_legends = T)	
suppressWarnings({
rect = rectangle_annotation_coordinates(ecotypes$Ecotype, clinical_filt$Ecotype)
})
decorate_heatmap_body("hmap", {
    grid.rect(x = unit(rect$x, "native"), y = unit(rect$y, "native"), width = unit(rect$w, "native"), height = unit(rect$h, "native"), hjust = 0, vjust = 1, gp = gpar(col = "white", fill = NA, lty = 1, lwd = 3))
})
tmp = dev.off()

png(file.path(output_dir, "heatmap_assigned_samples_viridis.png"), width = 8, height = 7, units = "in", res = 300)
draw(h, heatmap_legend_side = "bottom", annotation_legend_side = "bottom", merge_legends = T)	
decorate_heatmap_body("hmap", {
    grid.rect(x = unit(rect$x, "native"), y = unit(rect$y, "native"), width = unit(rect$w, "native"), height = unit(rect$h, "native"), hjust = 0, vjust = 1, gp = gpar(col = "white", fill = NA, lty = 1, lwd = 3))
})
tmp = dev.off()

h = heatmap_simple(small_H, top_annotation = clinical, top_columns = top_cols, 
	left_annotation = ecotypes, left_columns = c("Ecotype", "CellType", "State"),
	width = unit(5, "in"), height = unit(3, "in"), 
	legend_name = "State abundance",
	color_range = c(seq(0, quantile(small_H, .8), length.out = 8)), color_palette = c("black", brewer.pal(8, "YlGnBu")), raster_quality = 20)

pdf(file.path(output_dir, "heatmap_assigned_samples_YlGnBu.pdf"), width = 8, height = 7)
draw(h, heatmap_legend_side = "bottom", annotation_legend_side = "bottom", merge_legends = T)	
decorate_heatmap_body("hmap", {
    grid.rect(x = unit(rect$x, "native"), y = unit(rect$y, "native"), width = unit(rect$w, "native"), height = unit(rect$h, "native"), hjust = 0, vjust = 1, gp = gpar(col = "white", fill = NA, lty = 1, lwd = 3))
})
tmp = dev.off()

png(file.path(output_dir, "heatmap_assigned_samples_YlGnBu.png"), width = 8, height = 7, units = "in", res = 300)
draw(h, heatmap_legend_side = "bottom", annotation_legend_side = "bottom", merge_legends = T)	
decorate_heatmap_body("hmap", {
    grid.rect(x = unit(rect$x, "native"), y = unit(rect$y, "native"), width = unit(rect$w, "native"), height = unit(rect$h, "native"), hjust = 0, vjust = 1, gp = gpar(col = "white", fill = NA, lty = 1, lwd = 3))
})
tmp = dev.off()
# Out:
# Error in nrow(mat): object 'small_H' not found
# Traceback:
#
# 1. heatmap_simple(small_H, top_annotation = clinical_filt, top_columns = top_cols,
#  .     left_annotation = ecotypes, left_columns = c("Ecotype", "CellType",
#  .         "State"), width = unit(5, "in"), height = unit(3, "in"),
#  .     legend_name = "State abundance", color_range = seq(0, quantile(as.matrix(all_H),
#  .         0.9), length.out = 8), color_palette = c("white", viridis(8)),
#  .     raster_quality = 20)
# 2. nrow(mat)

# %% [markdown]
# ### Regular Ecotype Recovery

# %%
suppressPackageStartupMessages({
library(argparse)
source("lib/config.R") 
source("lib/multithreading.R")
})

# %%
suppressPackageStartupMessages({
library(cluster)
library(ggplot2)
library(viridis)
source("lib/misc.R")
source("lib/heatmaps.R")
source("lib/read_clinical.R")
})

# %%
args = commandArgs(T) 
# dataset = args[1]
# fractions = args[2]
# test_dataset = args[3]
# top_cols = args[4:length(args)]

#### NEW ARGUMENTS ADDED

# keyDir = args[1]
# inputDir = args[2]
# outputDir = args[3]
keyDir = "Test_12_Complete_Peng_Discovered_States_Ecotype_Discovery_PDSM_Updated_Recovery_SSM_Run_090222"
inputDir = "Test_12_Complete_Peng_Discovered_States_Ecotype_Discovery_PDSM_Updated_Recovery_SSM_Run_090222/TCGA_Recovery_090222/Inputs"
outputDir = "Test_12_Complete_Peng_Discovered_States_Ecotype_Discovery_PDSM_Updated_Recovery_SSM_Run_090222/TCGA_Recovery_090222"
top_cols = c("Ecotype")

if(is.na(top_cols[1]))
{
	top_cols = "Ecotype"
}
top_cols = unique(c(top_cols, "Ecotype"))

cat(paste0("Running ecotype recovery...\n"))

# key_dir = file.path("../EcoTyper", dataset, fractions, "Analysis", "rank_selection")
key_dir = file.path("/duo4/users/pchati/ecotyper/Generate_Cell_State_Abundances_Predefined_States_Test_Outputs", keyDir)

# states_dir = file.path("../EcoTyper", dataset, fractions, "Cell_States", "recovery", test_dataset)
# states_dir = file.path("/duo4/users/pchati/ecotyper/Generate_Cell_State_Abundances_Predefined_States_Test_Outputs", "Test_8_Peng_Discovered_States_EcoTyper_PDSM_Run_083022", "TCGA_Recovery_090122")
states_dir = file.path("/duo4/users/pchati/ecotyper/Generate_Cell_State_Abundances_Predefined_States_Test_Outputs", outputDir)

# inpput_dir = file.path("../EcoTyper", dataset, fractions, "Ecotypes", "discovery")
input_dir = file.path("/duo4/users/pchati/ecotyper/Generate_Cell_State_Abundances_Predefined_States_Test_Outputs", keyDir, "Ecotypes")

# output_dir = file.path("../EcoTyper", dataset, fractions, "Ecotypes", "recovery", test_dataset)
output_dir = file.path("/duo4/users/pchati/ecotyper/Generate_Cell_State_Abundances_Predefined_States_Test_Outputs", outputDir, "Ecotypes") 

dir.create(output_dir, recursive = T, showWarning = F) 

key = read.delim(file.path(key_dir, "rank_data.txt"))

# ecotypes = read.delim(file.path(inpput_dir, 'ecotypes.txt'), sep = '\t')
ecotypes = read.delim(file.path(input_dir, 'ecotypes.txt'), sep = '\t')

ecotypes$Ecotype = ecotype_to_factor(ecotypes$Ecotype)
ecotypes = ecotypes[order(ecotypes$Ecotype),]

all_H = NULL
all_classes_filt = NULL
# Out:
# Running ecotype recovery...

# %%
ecotypes
# Out:
#    CellType            State     InitialEcotype ID
# 1  Mast                S01       IE01           Mast_S01
# 2  Plasma              S02       IE01           Plasma_S02
# 3  Plasma              S06       IE01           Plasma_S06
# 4  Mast                S05       IE04           Mast_S05
# 5  B_cell              S04       IE04           B_cell_S04
# 6  Malignant_Malignant IC        IE04           Malignant_Malignant_IC
# 7  Endothelial         S03       IE04           Endothelial_S03
# 8  Mast                S04       IE05           Mast_S04
# 9  Fibroblast          myCAF     IE05           Fibroblast_myCAF
# 10 Endothelial         S04       IE05           Endothelial_S04
# 11 Plasma              S03       IE05           Plasma_S03
# 12 NK_T_cell_CD4_T     cell      IE05           NK_T_cell_CD4_T_cell
# 13 Stellate            S02       IE07           Stellate_S02
# 14 Malignant_Malignant Classical IE07           Malignant_Malignant_Classical
# 15 Monocyte_DC_TAM     SPP1      IE07           Monocyte_DC_TAM_SPP1
# 16 Stellate            S05       IE10           Stellate_S05
# 17 Fibroblast          iCAF      IE10           Fibroblast_iCAF
# 18 Malignant           Acinar    IE10           Malignant_Acinar
# 19 Endothelial         S02       IE10           Endothelial_S02
# 20 Acinar              S04       IE10           Acinar_S04
# 21 NK_T_cell_CD8_T     cell      IE10           NK_T_cell_CD8_T_cell_
# 22 Normal_Epithelial   S01       IE22           Normal_Epithelial_S01
# 23 Plasma              S05       IE22           Plasma_S05
# 24 Acinar              S02       IE22           Acinar_S02
#    Cell.type           Ecotype
# 1  Mast                E1
# 2  Plasma              E1
# 3  Plasma              E1
# 4  Mast                E2
# 5  B_cell              E2
# 6  Malignant_Malignant E2
# 7  Endothelial         E2
# 8  Mast                E3
# 9  Fibroblast          E3
# 10 Endothelial         E3
# 11 Plasma              E3
# 12 NK_T_cell_CD4_T     E3
# 13 Stellate            E4
# 14 Malignant_Malignant E4
# 15 Monocyte_DC_TAM     E4
# 16 Stellate            E5
# 17 Fibroblast          E5
# 18 Malignant           E5
# 19 Endothelial         E5
# 20 Acinar              E5
# 21 NK_T_cell_CD8_T     E5
# 22 Normal_Epithelial   E6
# 23 Plasma              E6
# 24 Acinar              E6

# %%
for(cell_type in key[,1])
{	
	#print(cell_type) 
	n_clusters = key[key[,1] == cell_type,2]
    
# 	classes = read.delim(file.path(states_dir, cell_type, n_clusters, 'state_abundances.txt'))
    classes = read.delim(file.path(states_dir, cell_type, 'state_abundances.txt'))

	rownames(classes) = paste0(cell_type, "_", rownames(classes))
	all_H = rbind(all_H, classes)

# 	classes = read.delim(file.path(states_dir, cell_type, n_clusters, 'state_assignment.txt'))
    classes = read.delim(file.path(states_dir, cell_type, 'state_assignment.txt'))
    
	clusters = ecotypes[ecotypes$CellType == cell_type,] 
	classes = classes[classes$State %in% clusters$State,]
	classes = classes[,c("ID", "State")]
	colnames(classes) = c('ID', cell_type)

	if(is.null(all_classes_filt))
	{
		all_classes_filt = classes
	}else{
		all_classes_filt = merge(all_classes_filt, classes, by = 'ID', all = T)
	}	
}

# %%
all_H
# ecotypes$ID
# Out:
#                                TCGA.OE.A75W.01A.12R.A32O.07
# Mast_S01                       1.837239e-08
# Mast_S02                       7.156981e-02
# Mast_S03                       1.028665e-01
# Mast_S05                       3.273235e-01
# Mast_S04                       4.982402e-01
# Stellate_S01                   1.473302e-01
# Stellate_S02                   1.533121e-01
# Stellate_S04                   1.063844e-01
# Stellate_S03                   1.740259e-16
# Stellate_S05                   5.929732e-01
# Fibroblast_myCAF               1.000000e+00
# Fibroblast_iCAF                5.145296e-15
# B_cell_S04                     6.038104e-01
# B_cell_S02                     1.841242e-01
# B_cell_S01                     1.706507e-01
# B_cell_S03                     4.141462e-02
# Malignant_Normal_Epithelial    7.362546e-03
# Malignant_Malignant_Cycling    3.981443e-02
# Malignant_Malignant_IC         1.003386e-01
# Malignant_Acinar               1.854439e-16
# Malignant_Malignant_Basal      7.562740e-02
# Malignant_Malignant_Classical  7.768570e-01
# Endothelial_S01                1.215052e-01
# Endothelial_S03                1.482712e-01
# Endothelial_S04                1.455517e-01
# Endothelial_S02                5.846718e-01
# Monocyte_DC_TAM_SPP1           4.048307e-01
# Monocyte_DC_DC                 2.845256e-01
# Monocyte_DC_DC_LAMP3           1.049535e-01
# Monocyte_DC_TAM_FCN1           1.635276e-01
# Monocyte_DC_pDC                4.128409e-02
# Monocyte_DC_TAM_C1QC           8.786180e-04
# Normal_Epithelial_S01          7.924924e-01
# Normal_Epithelial_S02          2.380799e-03
# Normal_Epithelial_S03          2.051268e-01
# Plasma_S01                     4.547090e-01
# Plasma_S02                     9.260245e-03
# Plasma_S04                     3.562353e-01
# Plasma_S06                     7.917135e-02
# Plasma_S03                     2.780135e-03
# Plasma_S05                     9.784395e-02
# Acinar_S01                     1.681120e-06
# Acinar_S03                     2.258678e-01
# Acinar_S04                     3.193062e-01
# Acinar_S02                     4.548244e-01
# NK_T_cell_CD8_T_cell_          4.526288e-01
# NK_T_cell_Treg                 1.463856e-01
# NK_T_cell_T_cell_Proliferating 1.929507e-16
# NK_T_cell_CD4_T_cell           2.867323e-02
# NK_T_cell_NK                   1.597401e-01
# NK_T_cell_CD8_T_cell_Exhausted 2.125723e-01
#                                TCGA.2J.AABT.01A.11R.A41B.07
# Mast_S01                       1.023853e-01
# Mast_S02                       5.521288e-02
# Mast_S03                       5.197330e-01
# Mast_S05                       9.138324e-02
# Mast_S04                       2.312856e-01
# Stellate_S01                   1.563455e-16
# Stellate_S02                   7.469972e-04
# Stellate_S04                   1.371438e-01
# Stellate_S03                   6.257332e-01
# Stellate_S05                   2.363761e-01
# Fibroblast_myCAF               6.853641e-02
# Fibroblast_iCAF                9.314636e-01
# B_cell_S04                     6.645924e-01
# B_cell_S02                     3.154814e-01
# B_cell_S01                     2.090193e-16
# B_cell_S03                     1.992624e-02
# Malignant_Normal_Epithelial    1.037625e-01
# Malignant_Malignant_Cycling    1.957003e-16
# Malignant_Malignant_IC         2.034534e-02
# Malignant_Acinar               3.362712e-01
# Malignant_Malignant_Basal      1.360675e-03
# Malignant_Malignant_Classical  5.382603e-01
# Endothelial_S01                3.552581e-02
# Endothelial_S03                5.345761e-02
# Endothelial_S04                4.089917e-01
# Endothelial_S02                5.020249e-01
# Monocyte_DC_TAM_SPP1           2.056805e-02
# Monocyte_DC_DC                 9.722570e-02
# Monocyte_DC_DC_LAMP3           1.558595e-02
# Monocyte_DC_TAM_FCN1           4.136519e-01
# Monocyte_DC_pDC                4.725406e-02
# Monocyte_DC_TAM_C1QC           4.057143e-01
# Normal_Epithelial_S01          2.973520e-02
# Normal_Epithelial_S02          9.377898e-01
# Normal_Epithelial_S03          3.247498e-02
# Plasma_S01                     1.773426e-01
# Plasma_S02                     1.881354e-02
# Plasma_S04                     5.601201e-01
# Plasma_S06                     2.008353e-16
# Plasma_S03                     1.875448e-01
# Plasma_S05                     5.617887e-02
# Acinar_S01                     1.599699e-11
# Acinar_S03                     5.315517e-01
# Acinar_S04                     4.684327e-01
# Acinar_S02                     1.559816e-05
# NK_T_cell_CD8_T_cell_          1.852561e-01
# NK_T_cell_Treg                 2.718988e-01
# NK_T_cell_T_cell_Proliferating 2.834316e-16
# NK_T_cell_CD4_T_cell           4.570683e-01
# NK_T_cell_NK                   7.474949e-08
# Endothelial_S01                9.643896e-02
# Endothelial_S03                1.305366e-01
# Endothelial_S04                3.199373e-01
# Endothelial_S02                4.530872e-01
# Monocyte_DC_TAM_SPP1           4.906080e-01
# Monocyte_DC_DC                 2.807035e-01
# Monocyte_DC_DC_LAMP3           2.992457e-02
# Monocyte_DC_TAM_FCN1           9.573289e-02
# Monocyte_DC_pDC                3.145181e-03
# Monocyte_DC_TAM_C1QC           9.988592e-02
# Normal_Epithelial_S01          2.911165e-01
# Normal_Epithelial_S02          6.770147e-01
# Normal_Epithelial_S03          3.186882e-02
# Plasma_S01                     1.739299e-01
# Plasma_S02                     8.531204e-02
# Plasma_S04                     4.284898e-01
# Plasma_S06                     9.814575e-02
# Plasma_S03                     1.904064e-01
# Plasma_S05                     2.371618e-02
# Acinar_S01                     3.081852e-03
# Acinar_S03                     2.803583e-01
# Acinar_S04                     6.225777e-01
# Acinar_S02                     9.398215e-02
# NK_T_cell_CD8_T_cell_          1.700145e-01
# NK_T_cell_Treg                 3.737086e-01
# NK_T_cell_T_cell_Proliferating 6.185911e-05
# NK_T_cell_CD4_T_cell           1.518813e-01
# NK_T_cell_NK                   3.043338e-01
# NK_T_cell_CD8_T_cell_Exhausted 1.919029e-12
#                                TCGA.2J.AAB6.01A.11R.A41B.07
# Mast_S01                       6.801915e-02
# Mast_S02                       4.031057e-02
# Mast_S03                       3.319172e-01
# Mast_S05                       1.319016e-01
# Mast_S04                       4.278515e-01
# Stellate_S01                   7.409656e-09
# Stellate_S02                   5.308810e-01
# Stellate_S04                   1.617473e-01
# Stellate_S03                   1.964950e-02
# Stellate_S05                   2.877223e-01
# Fibroblast_myCAF               9.768898e-01
# Fibroblast_iCAF                2.311023e-02
# B_cell_S04                     4.643984e-01
# B_cell_S02                     9.328502e-02
# B_cell_S01                     3.904314e-01
# B_cell_S03                     5.188517e-02
# Malignant_Normal_Epithelial    2.064006e-01
# Malignant_Malignant_Cycling    4.111992e-01
# Malignant_Malignant_IC         1.877360e-01
# Malignant_Acinar               2.021678e-16
# Malignant_Malignant_Basal      1.946642e-01
# Malignant_Malignant_Classical  4.958245e-15
# Endothelial_S01                1.368211e-01
# Endothelial_S03                2.630771e-01
# Endothelial_S04                3.048514e-01
# Endothelial_S02                2.952504e-01
# Monocyte_DC_TAM_SPP1           7.279232e-01
# Monocyte_DC_DC                 6.738669e-02
# Monocyte_DC_DC_LAMP3           1.971296e-16
# Monocyte_DC_TAM_FCN1           2.046901e-01
# Monocyte_DC_pDC                8.242377e-10
# Monocyte_DC_TAM_C1QC           2.925620e-11
# Normal_Epithelial_S01          3.539514e-01
# Normal_Epithelial_S02          4.002927e-01
# Normal_Epithelial_S03          2.457559e-01
# Plasma_S01                     1.319001e-01
# Plasma_S02                     1.218827e-03
# Plasma_S04                     4.696020e-01
# Plasma_S06                     6.503955e-02
# Plasma_S03                     3.002135e-02
# Plasma_S05                     3.022182e-01
# Acinar_S01                     1.102693e-01
# Acinar_S03                     3.747239e-01
# Acinar_S04                     3.624146e-01
# Acinar_S02                     1.525923e-01
# NK_T_cell_CD8_T_cell_          5.571346e-01
# NK_T_cell_Treg                 2.613639e-01
# NK_T_cell_T_cell_Proliferating 1.542365e-16
# NK_T_cell_CD4_T_cell           2.854681e-02
# NK_T_cell_NK                   7.446562e-02
# NK_T_cell_CD8_T_cell_Exhausted 7.848898e-02
#                                TCGA.LB.A8F3.01A.11R.A36G.07
# Mast_S01                       6.261607e-03
# Mast_S02                       7.065761e-02
# Mast_S03                       1.062684e-02
# Mast_S05                       1.101191e-01
# Mast_S04                       8.023348e-01
# Stellate_S01                   2.313841e-02
# Stellate_S02                   1.342454e-01
# Stellate_S04                   4.717450e-02
# Stellate_S03                   1.546529e-16
# Stellate_S05                   7.954417e-01
# Fibroblast_myCAF               6.449829e-01
# Fibroblast_iCAF                3.550171e-01
# B_cell_S04                     7.904013e-01
# B_cell_S02                     1.863788e-01
# B_cell_S01                     3.002358e-03
# B_cell_S03                     2.021756e-02
# Malignant_Normal_Epithelial    1.611382e-02
# Malignant_Malignant_Cycling    1.589887e-16
# Malignant_Malignant_IC         9.280648e-02
# Malignant_Acinar               7.795948e-01
# Malignant_Malignant_Basal      4.046857e-02
# Malignant_Malignant_Classical  7.101638e-02
# Endothelial_S01                1.363757e-01
# Endothelial_S03                1.873685e-06
# Endothelial_S04                1.758823e-01
# Endothelial_S02                6.877401e-01
# Monocyte_DC_TAM_SPP1           2.438445e-02
# Monocyte_DC_DC                 3.788372e-04
# Monocyte_DC_DC_LAMP3           1.288099e-01
# Monocyte_DC_TAM_FCN1           7.861840e-01
# Monocyte_DC_pDC                6.024288e-02
# Monocyte_DC_TAM_C1QC           1.418056e-16
# Normal_Epithelial_S01          6.525259e-01
# Normal_Epithelial_S02          1.805114e-16
# Normal_Epithelial_S03          3.474741e-01
# Plasma_S01                     3.923358e-01
# Plasma_S02                     4.066480e-02
# Plasma_S04                     4.320240e-01
# Plasma_S06                     6.613388e-03
# Plasma_S03                     9.746928e-02
# Plasma_S05                     3.089268e-02
# Acinar_S01                     1.882105e-02
# Acinar_S03                     1.571982e-01
# Acinar_S04                     1.867134e-01
# Acinar_S02                     6.372673e-01
# NK_T_cell_CD8_T_cell_          3.391483e-01
# NK_T_cell_Treg                 1.330902e-01
# NK_T_cell_T_cell_Proliferating 1.183906e-16
# NK_T_cell_CD4_T_cell           1.932253e-01
# NK_T_cell_NK                   3.345362e-01
# NK_T_cell_CD8_T_cell_Exhausted 3.461296e-15
#                                TCGA.HZ.A4BH.01A.11R.A26U.07
# Mast_S01                       1.359531e-01
# Mast_S02                       1.563146e-01
# Mast_S03                       7.228672e-02
# Mast_S05                       2.612965e-01
# Mast_S04                       3.741491e-01
# Stellate_S01                   9.437510e-15
# Stellate_S02                   4.368976e-01
# Stellate_S04                   2.732097e-01
# Stellate_S03                   2.344704e-01
# Stellate_S05                   5.542230e-02
# Fibroblast_myCAF               4.089707e-02
# Fibroblast_iCAF                9.591029e-01
# B_cell_S04                     1.777047e-01
# B_cell_S02                     5.304070e-01
# B_cell_S01                     2.853964e-01
# B_cell_S03                     6.491784e-03
# Malignant_Normal_Epithelial    3.847782e-01
# Malignant_Malignant_Cycling    2.254442e-01
# Malignant_Malignant_IC         9.448048e-02
# Malignant_Acinar               2.779789e-16
# Malignant_Malignant_Basal      1.692046e-01
# Malignant_Malignant_Classical  1.260925e-01
# Endothelial_S01                3.532631e-03
# Endothelial_S03                4.346263e-01
# Endothelial_S04                3.135114e-01
# Endothelial_S02                2.483297e-01
# Monocyte_DC_TAM_SPP1           2.407822e-02
# Monocyte_DC_DC                 2.149116e-01
# Monocyte_DC_DC_LAMP3           8.939836e-02
# Monocyte_DC_TAM_FCN1           6.412473e-02
# Monocyte_DC_pDC                2.322147e-02
# Monocyte_DC_TAM_C1QC           5.842657e-01
# Normal_Epithelial_S01          4.258954e-02
# Normal_Epithelial_S02          9.261755e-01
# Normal_Epithelial_S03          3.123496e-02
# Plasma_S01                     6.056528e-02
# Plasma_S02                     1.877206e-01
# Plasma_S04                     2.936049e-01
# Plasma_S06                     1.890490e-01
# Plasma_S03                     1.304274e-01
# Plasma_S05                     1.386328e-01
# Acinar_S01                     1.226788e-02
# Acinar_S03                     5.990703e-01
# Acinar_S04                     3.578206e-01
# Acinar_S02                     3.084123e-02
# NK_T_cell_CD8_T_cell_          2.152546e-01
# NK_T_cell_Treg                 1.665778e-01
# NK_T_cell_T_cell_Proliferating 3.411215e-01
# NK_T_cell_CD4_T_cell           2.138089e-01
# NK_T_cell_NK                   6.323716e-02
# NK_T_cell_CD8_T_cell_Exhausted 7.108107e-11
#                                TCGA.IB.7646.01A.11R.2156.07
# Mast_S01                       9.693027e-02
# Mast_S02                       1.136387e-01
# Mast_S03                       7.335350e-02
# Mast_S05                       8.435258e-02
# Mast_S04                       6.317250e-01
# Stellate_S01                   4.805305e-03
# Stellate_S02                   5.045423e-01
# Stellate_S04                   3.062897e-01
# Stellate_S03                   4.701814e-02
# Stellate_S05                   1.373445e-01
# Fibroblast_myCAF               6.711805e-01
# Fibroblast_iCAF                3.288195e-01
# B_cell_S04                     3.286894e-01
# B_cell_S02                     1.930064e-01
# B_cell_S01                     4.664475e-01
# B_cell_S03                     1.185664e-02
# Malignant_Normal_Epithelial    7.947162e-03
# Malignant_Malignant_Cycling    5.031981e-01
# Malignant_Malignant_IC         4.309646e-01
# Malignant_Acinar               5.822913e-10
# Malignant_Malignant_Basal      5.394732e-02
# Malignant_Malignant_Classical  3.942883e-03
# Endothelial_S01                8.960595e-02
# Endothelial_S03                7.265346e-02
# Endothelial_S04                4.771470e-01
# Endothelial_S02                3.605936e-01
# Monocyte_DC_TAM_SPP1           2.982359e-01
# Monocyte_DC_DC                 7.461902e-03
# Monocyte_DC_DC_LAMP3           3.036045e-02
# Monocyte_DC_TAM_FCN1           4.380609e-01
# Monocyte_DC_pDC                1.852856e-16
# Monocyte_DC_TAM_C1QC           2.258808e-01
# Normal_Epithelial_S01          1.541390e-01
# Normal_Epithelial_S02          5.970326e-01
# Normal_Epithelial_S03          2.488284e-01
# Plasma_S01                     3.645047e-01
# Plasma_S02                     1.087585e-02
# Plasma_S04                     2.815914e-01
# Plasma_S06                     1.067076e-01
# Plasma_S03                     2.094903e-01
# Plasma_S05                     2.683022e-02
# Acinar_S01                     6.369514e-07
# Acinar_S03                     5.200325e-01
# Acinar_S04                     3.741688e-01
# Acinar_S02                     1.057981e-01
# NK_T_cell_CD8_T_cell_          3.199609e-01
# NK_T_cell_Treg                 1.077196e-01
# NK_T_cell_T_cell_Proliferating 2.479400e-15
# NK_T_cell_CD4_T_cell           1.710662e-01
# NK_T_cell_NK                   1.585717e-01
# NK_T_cell_CD8_T_cell_Exhausted 2.426816e-01
#                                TCGA.2J.AAB9.01A.11R.A41B.07
# Mast_S01                       1.642440e-01
# Mast_S02                       5.648843e-02
# Mast_S03                       2.200943e-01
# Mast_S05                       1.620730e-01
# Mast_S04                       3.971002e-01
# Stellate_S01                   3.810837e-16
# Stellate_S02                   2.842607e-01
# Stellate_S04                   2.370154e-01
# Stellate_S03                   1.601290e-01
# Stellate_S05                   3.185949e-01
# Fibroblast_myCAF               1.672175e-01
# Fibroblast_iCAF                8.327825e-01
# B_cell_S04                     6.928502e-01
# B_cell_S02                     3.047330e-01
# B_cell_S01                     2.416803e-03
# B_cell_S03                     3.391175e-16
# Malignant_Normal_Epithelial    6.094964e-02
# Malignant_Malignant_Cycling    2.692378e-16
# Malignant_Malignant_IC         2.336527e-04
# Malignant_Acinar               8.556276e-01
# Malignant_Malignant_Basal      8.252208e-02
# Malignant_Malignant_Classical  6.670405e-04
# Endothelial_S01                7.612522e-02
# Endothelial_S03                1.541175e-01
# Endothelial_S04                2.732255e-01
# Endothelial_S02                4.965317e-01
# Monocyte_DC_TAM_SPP1           4.699642e-02
# Monocyte_DC_DC                 2.199647e-01
# Monocyte_DC_DC_LAMP3           7.084101e-02
# Monocyte_DC_TAM_FCN1           4.464354e-01
# Monocyte_DC_pDC                1.008089e-01
# Monocyte_DC_TAM_C1QC           1.149535e-01
# Normal_Epithelial_S01          1.055880e-01
# Normal_Epithelial_S02          7.527395e-01
# Normal_Epithelial_S03          1.416725e-01
# Plasma_S01                     2.254761e-01
# Plasma_S02                     1.163850e-01
# Plasma_S04                     4.404857e-01
# Plasma_S06                     1.509079e-02
# Plasma_S03                     1.957384e-01
# Plasma_S05                     6.824027e-03
# Acinar_S01                     4.078226e-02
# Acinar_S03                     1.349591e-01
# Acinar_S04                     2.484468e-01
# Acinar_S02                     5.758119e-01
# NK_T_cell_CD8_T_cell_          8.717546e-02
# NK_T_cell_Treg                 1.810648e-01
# NK_T_cell_T_cell_Proliferating 3.424283e-16
# NK_T_cell_CD4_T_cell           4.000960e-01
# NK_T_cell_NK                   3.316637e-01
# NK_T_cell_CD8_T_cell_Exhausted 3.424283e-16
#                                TCGA.2J.AAB4.01A.12R.A41B.07 ⋯
# Mast_S01                       1.589608e-01                 ⋯
# Mast_S02                       1.748052e-01                 ⋯
# Mast_S03                       1.515629e-01                 ⋯
# Mast_S05                       2.059356e-01                 ⋯
# Mast_S04                       3.087355e-01                 ⋯
# Stellate_S01                   6.498758e-09                 ⋯
# Stellate_S02                   3.262707e-01                 ⋯
# Stellate_S04                   2.886221e-01                 ⋯
# Stellate_S03                   1.631092e-02                 ⋯
# Stellate_S05                   3.687963e-01                 ⋯
# Fibroblast_myCAF               2.029042e-01                 ⋯
# Fibroblast_iCAF                7.970958e-01                 ⋯
# B_cell_S04                     3.888428e-01                 ⋯
# B_cell_S02                     4.141116e-01                 ⋯
# B_cell_S01                     1.619032e-01                 ⋯
# B_cell_S03                     3.514236e-02                 ⋯
# Malignant_Normal_Epithelial    2.272436e-01                 ⋯
# Malignant_Malignant_Cycling    5.626985e-02                 ⋯
# Malignant_Malignant_IC         6.120539e-01                 ⋯
# Malignant_Acinar               3.415874e-02                 ⋯
# Malignant_Malignant_Basal      2.458387e-16                 ⋯
# Malignant_Malignant_Classical  7.027390e-02                 ⋯
# Endothelial_S01                1.351162e-01                 ⋯
# Endothelial_S03                1.405205e-01                 ⋯
# Endothelial_S04                3.216002e-01                 ⋯
# Endothelial_S02                4.027632e-01                 ⋯
# Monocyte_DC_TAM_SPP1           3.146650e-01                 ⋯
# Monocyte_DC_DC                 2.772754e-01                 ⋯
# Monocyte_DC_DC_LAMP3           5.978571e-02                 ⋯
# Monocyte_DC_TAM_FCN1           1.131033e-01                 ⋯
# Monocyte_DC_pDC                2.435829e-03                 ⋯
# Monocyte_DC_TAM_C1QC           2.327347e-01                 ⋯
# Normal_Epithelial_S01          3.891460e-02                 ⋯
# Normal_Epithelial_S02          9.334113e-01                 ⋯
# Normal_Epithelial_S03          2.767414e-02                 ⋯
# Plasma_S01                     2.114958e-01                 ⋯
# Plasma_S02                     7.576246e-02                 ⋯
# Plasma_S04                     2.476679e-01                 ⋯
# Plasma_S06                     1.141729e-01                 ⋯
# Plasma_S03                     2.656994e-01                 ⋯
# Plasma_S05                     8.520150e-02                 ⋯
# Acinar_S01                     2.408687e-03                 ⋯
# Acinar_S03                     2.129017e-01                 ⋯
# Acinar_S04                     7.198675e-01                 ⋯
# Acinar_S02                     6.482215e-02                 ⋯
# NK_T_cell_CD8_T_cell_          6.415494e-01                 ⋯
# NK_T_cell_Treg                 8.606294e-02                 ⋯
# NK_T_cell_T_cell_Proliferating 2.460839e-02                 ⋯
# NK_T_cell_CD4_T_cell           2.197715e-01                 ⋯
# NK_T_cell_NK                   2.797113e-02                 ⋯
# NK_T_cell_CD8_T_cell_Exhausted 3.662462e-05                 ⋯
#                                TCGA.3A.A9I7.01A.21R.A38C.07
# Mast_S01                       2.161257e-01
# Mast_S02                       4.032366e-02
# Mast_S03                       1.132788e-01
# Mast_S05                       2.372225e-01
# Mast_S04                       3.930494e-01
# Stellate_S01                   1.790763e-02
# Stellate_S02                   2.375201e-01
# Stellate_S04                   1.093899e-01
# Stellate_S03                   2.784137e-01
# Stellate_S05                   3.567687e-01
# Fibroblast_myCAF               8.399661e-01
# Fibroblast_iCAF                1.600339e-01
# B_cell_S04                     3.882147e-01
# B_cell_S02                     5.735457e-01
# B_cell_S01                     5.688739e-03
# B_cell_S03                     3.255083e-02
# Malignant_Normal_Epithelial    3.502304e-02
# Malignant_Malignant_Cycling    2.583122e-16
# Malignant_Malignant_IC         1.825554e-02
# Malignant_Acinar               8.821171e-02
# Malignant_Malignant_Basal      3.863506e-02
# Malignant_Malignant_Classical  8.198747e-01
# Endothelial_S01                9.802539e-02
# Endothelial_S03                8.335793e-02
# Endothelial_S04                3.599361e-01
# Endothelial_S02                4.586806e-01
# Monocyte_DC_TAM_SPP1           6.171226e-05
# Monocyte_DC_DC                 2.159151e-01
# Monocyte_DC_DC_LAMP3           2.377147e-02
# Monocyte_DC_TAM_FCN1           2.736328e-01
# Monocyte_DC_pDC                1.006272e-01
# Monocyte_DC_TAM_C1QC           3.859917e-01
# Normal_Epithelial_S01          2.386518e-02
# Normal_Epithelial_S02          7.376884e-01
# Normal_Epithelial_S03          2.384464e-01
# Plasma_S01                     1.196155e-01
# Plasma_S02                     1.745865e-02
# Plasma_S04                     2.715927e-01
# Plasma_S06                     4.293731e-02
# Plasma_S03                     1.310120e-01
# Plasma_S05                     4.173838e-01
# Acinar_S01                     1.456858e-04
# Acinar_S03                     3.341522e-01
# Acinar_S04                     3.186360e-01
# Acinar_S02                     3.470661e-01
# NK_T_cell_CD8_T_cell_          1.355112e-01
# NK_T_cell_Treg                 3.937462e-02
# NK_T_cell_T_cell_Proliferating 6.870734e-02
# NK_T_cell_CD4_T_cell           4.763230e-01
# NK_T_cell_NK                   1.380232e-01
# NK_T_cell_CD8_T_cell_Exhausted 1.420606e-01
#                                TCGA.IB.7890.01A.12R.2204.07
# Mast_S01                       8.550230e-02
# Mast_S02                       3.353875e-02
# Mast_S03                       1.504955e-01
# Mast_S05                       3.964098e-01
# Mast_S04                       3.340537e-01
# Stellate_S01                   2.088510e-16
# Stellate_S02                   6.209859e-01
# Stellate_S04                   1.480827e-01
# Stellate_S03                   2.244419e-01
# Stellate_S05                   6.489477e-03
# Fibroblast_myCAF               8.802105e-01
# Fibroblast_iCAF                1.197895e-01
# B_cell_S04                     5.242829e-01
# B_cell_S02                     4.646825e-01
# B_cell_S01                     3.401920e-03
# B_cell_S03                     7.632773e-03
# Malignant_Normal_Epithelial    3.303254e-01
# Malignant_Malignant_Cycling    3.213455e-02
# Malignant_Malignant_IC         4.631781e-01
# Malignant_Acinar               2.517369e-13
# Malignant_Malignant_Basal      2.345166e-16
# Malignant_Malignant_Classical  1.743620e-01
# Endothelial_S01                8.872700e-02
# Endothelial_S03                4.065995e-01
# Endothelial_S04                2.419161e-01
# Endothelial_S02                2.627574e-01
# Monocyte_DC_TAM_SPP1           1.684890e-01
# Monocyte_DC_DC                 3.416762e-12
# Monocyte_DC_DC_LAMP3           2.452570e-16
# Monocyte_DC_TAM_FCN1           1.791872e-01
# Monocyte_DC_pDC                2.218358e-02
# Monocyte_DC_TAM_C1QC           6.301402e-01
# Normal_Epithelial_S01          3.750135e-04
# Normal_Epithelial_S02          8.561808e-01
# Normal_Epithelial_S03          1.434441e-01
# Plasma_S01                     2.798222e-01
# Plasma_S02                     1.571643e-02
# Plasma_S04                     5.728040e-01
# Plasma_S06                     1.967219e-16
# Plasma_S03                     1.014059e-01
# Plasma_S05                     3.025145e-02
# Acinar_S01                     1.623057e-02
# Acinar_S03                     6.502947e-01
# Acinar_S04                     2.814825e-01
# Acinar_S02                     5.199216e-02
# NK_T_cell_CD8_T_cell_          3.030890e-01
# NK_T_cell_Treg                 9.828386e-02
# NK_T_cell_T_cell_Proliferating 1.853038e-16
# NK_T_cell_CD4_T_cell           4.286769e-01
# NK_T_cell_NK                   1.695942e-01
# NK_T_cell_CD8_T_cell_Exhausted 3.559977e-04
#                                TCGA.2J.AABH.01A.21R.A41B.07
# Mast_S01                       2.882398e-02
# Mast_S02                       2.809779e-02
# Mast_S03                       3.413532e-01
# Mast_S05                       1.479570e-01
# Mast_S04                       4.537680e-01
# Stellate_S01                   1.411345e-02
# Stellate_S02                   9.093187e-02
# Stellate_S04                   1.814183e-01
# Stellate_S03                   3.134820e-14
# Stellate_S05                   7.135364e-01
# Fibroblast_myCAF               5.230810e-01
# Fibroblast_iCAF                4.769190e-01
# B_cell_S04                     8.088482e-01
# B_cell_S02                     1.861579e-01
# B_cell_S01                     2.220802e-04
# B_cell_S03                     4.771792e-03
# Malignant_Normal_Epithelial    2.667773e-01
# Malignant_Malignant_Cycling    2.577024e-16
# Malignant_Malignant_IC         1.462839e-01
# Malignant_Acinar               5.409926e-02
# Malignant_Malignant_Basal      2.577024e-16
# Malignant_Malignant_Classical  5.328395e-01
# Endothelial_S01                1.844240e-01
# Endothelial_S03                7.988412e-02
# Endothelial_S04                2.035260e-01
# Endothelial_S02                5.321659e-01
# Monocyte_DC_TAM_SPP1           3.543824e-01
# Monocyte_DC_DC                 1.045454e-01
# Monocyte_DC_DC_LAMP3           1.039532e-01
# Monocyte_DC_TAM_FCN1           4.240493e-01
# Monocyte_DC_pDC                1.306966e-02
# Monocyte_DC_TAM_C1QC           1.844635e-11
# Normal_Epithelial_S01          2.664027e-16
# Normal_Epithelial_S02          7.645185e-01
# Normal_Epithelial_S03          2.354815e-01
# Plasma_S01                     1.105386e-01
# Plasma_S02                     1.143451e-02
# Plasma_S04                     7.838624e-01
# Plasma_S06                     2.320563e-16
# Plasma_S03                     7.968975e-02
# Plasma_S05                     1.447479e-02
# Acinar_S01                     2.914090e-16
# Acinar_S03                     7.092294e-02
# Acinar_S04                     6.173523e-01
# Acinar_S02                     3.117247e-01
# NK_T_cell_CD8_T_cell_          7.312701e-01
# NK_T_cell_Treg                 1.304179e-01
# NK_T_cell_T_cell_Proliferating 2.029003e-16
# NK_T_cell_CD4_T_cell           1.376857e-01
# NK_T_cell_NK                   6.262774e-04
# NK_T_cell_CD8_T_cell_Exhausted 1.458033e-12
#                                TCGA.IB.AAUQ.01A.22R.A41I.07
# Mast_S01                       2.392311e-02
# Mast_S02                       1.471647e-01
# Mast_S03                       7.057321e-02
# Mast_S05                       4.451890e-01
# Mast_S04                       3.131500e-01
# Stellate_S01                   1.030458e-01
# Stellate_S02                   3.169423e-01
# Stellate_S04                   2.033438e-01
# Stellate_S03                   3.193644e-01
# Stellate_S05                   5.730370e-02
# Fibroblast_myCAF               7.073255e-01
# Fibroblast_iCAF                2.926745e-01
# B_cell_S04                     5.721940e-01
# B_cell_S02                     2.814334e-01
# B_cell_S01                     1.085849e-01
# B_cell_S03                     3.778762e-02
# Malignant_Normal_Epithelial    3.565609e-01
# Malignant_Malignant_Cycling    3.225513e-05
# Malignant_Malignant_IC         3.700847e-01
# Malignant_Acinar               5.181094e-02
# Malignant_Malignant_Basal      2.215112e-01
# Malignant_Malignant_Classical  2.786509e-16
# Endothelial_S01                1.495318e-01
# Endothelial_S03                4.233288e-01
# Endothelial_S04                8.668407e-02
# Endothelial_S02                3.404553e-01
# Monocyte_DC_TAM_SPP1           3.074574e-01
# Monocyte_DC_DC                 2.005609e-10
# Monocyte_DC_DC_LAMP3           3.173448e-03
# Monocyte_DC_TAM_FCN1           4.167596e-01
# Monocyte_DC_pDC                1.496547e-02
# Monocyte_DC_TAM_C1QC           2.576441e-01
# Normal_Epithelial_S01          3.791336e-01
# Normal_Epithelial_S02          5.686329e-01
# Normal_Epithelial_S03          5.223358e-02
# Plasma_S01                     1.358721e-01
# Plasma_S02                     2.145121e-01
# Plasma_S04                     4.059375e-02
# Plasma_S06                     3.093685e-03
# Plasma_S03                     2.618470e-01
# Plasma_S05                     3.440813e-01
# Acinar_S01                     2.144794e-02
# Acinar_S03                     2.729052e-01
# Acinar_S04                     4.554417e-01
# Acinar_S02                     2.502051e-01
# NK_T_cell_CD8_T_cell_          6.177619e-01
# NK_T_cell_Treg                 1.912207e-01
# NK_T_cell_T_cell_Proliferating 2.529945e-16
# NK_T_cell_CD4_T_cell           9.565429e-02
# NK_T_cell_NK                   8.621749e-02
# NK_T_cell_CD8_T_cell_Exhausted 9.145692e-03
#                                TCGA.IB.A5SO.01A.11R.A32O.07
# Mast_S01                       9.494789e-02
# Mast_S02                       1.968151e-01
# Mast_S03                       2.998111e-01
# Mast_S05                       2.303817e-01
# Mast_S04                       1.780443e-01
# Stellate_S01                   7.225273e-16
# Stellate_S02                   2.939906e-01
# Stellate_S04                   4.513881e-01
# Stellate_S03                   1.581290e-01
# Stellate_S05                   9.649225e-02
# Fibroblast_myCAF               3.869161e-01
# Fibroblast_iCAF                6.130839e-01
# B_cell_S04                     5.863350e-01
# B_cell_S02                     4.099310e-01
# B_cell_S01                     3.647668e-03
# B_cell_S03                     8.623649e-05
# Malignant_Normal_Epithelial    3.273071e-01
# Malignant_Malignant_Cycling    3.391368e-16
# Malignant_Malignant_IC         1.619585e-01
# Malignant_Acinar               2.102362e-02
# Malignant_Malignant_Basal      7.400418e-02
# Malignant_Malignant_Classical  4.157066e-01
# Endothelial_S01                4.042480e-02
# Endothelial_S03                2.653138e-01
# Endothelial_S04                3.509904e-01
# Endothelial_S02                3.432710e-01
# Monocyte_DC_TAM_SPP1           5.858886e-11
# Monocyte_DC_DC                 1.384881e-06
# Monocyte_DC_DC_LAMP3           5.255380e-02
# Monocyte_DC_TAM_FCN1           1.861080e-01
# Monocyte_DC_pDC                1.525157e-02
# Monocyte_DC_TAM_C1QC           7.460852e-01
# Normal_Epithelial_S01          1.901991e-02
# Normal_Epithelial_S02          9.459457e-01
# Normal_Epithelial_S03          3.503436e-02
# Plasma_S01                     1.084646e-01
# Plasma_S02                     2.529344e-01
# Plasma_S04                     3.312908e-01
# Plasma_S06                     3.920012e-02
# Plasma_S03                     1.316277e-01
# Plasma_S05                     1.364824e-01
# Acinar_S01                     1.239233e-02
# Acinar_S03                     4.138043e-01
# Acinar_S04                     4.737157e-01
# Acinar_S02                     1.000877e-01
# NK_T_cell_CD8_T_cell_          1.741169e-01
# NK_T_cell_Treg                 2.045786e-01
# NK_T_cell_T_cell_Proliferating 1.839425e-01
# NK_T_cell_CD4_T_cell           3.150791e-01
# NK_T_cell_NK                   1.222828e-01
# NK_T_cell_CD8_T_cell_Exhausted 2.246009e-10
#                                TCGA.2J.AABF.01A.31R.A41B.07
# Mast_S01                       1.230014e-01
# Mast_S02                       2.047336e-01
# Mast_S03                       1.050808e-01
# Mast_S05                       3.199756e-01
# Mast_S04                       2.472087e-01
# Stellate_S01                   1.020415e-01
# Stellate_S02                   4.629352e-01
# Stellate_S04                   2.069656e-01
# Stellate_S03                   2.047103e-01
# Stellate_S05                   2.334744e-02
# Fibroblast_myCAF               5.262233e-16
# Fibroblast_iCAF                1.000000e+00
# B_cell_S04                     8.946908e-02
# B_cell_S02                     3.832261e-01
# B_cell_S01                     5.197821e-01
# B_cell_S03                     7.522704e-03
# Malignant_Normal_Epithelial    2.873068e-01
# Malignant_Malignant_Cycling    3.118005e-01
# Malignant_Malignant_IC         1.803274e-01
# Malignant_Acinar               1.618727e-01
# Malignant_Malignant_Basal      5.869247e-02
# Malignant_Malignant_Classical  9.745969e-08
# Endothelial_S01                1.526433e-01
# Endothelial_S03                2.109447e-01
# Endothelial_S04                3.711665e-01
# Endothelial_S02                2.652455e-01
# Monocyte_DC_TAM_SPP1           8.617499e-02
# Monocyte_DC_DC                 1.225482e-01
# Monocyte_DC_DC_LAMP3           1.524460e-02
# Monocyte_DC_TAM_FCN1           9.258081e-02
# Monocyte_DC_pDC                1.486418e-02
# Monocyte_DC_TAM_C1QC           6.685872e-01
# Normal_Epithelial_S01          4.843262e-02
# Normal_Epithelial_S02          9.085077e-01
# Normal_Epithelial_S03          4.305970e-02
# Plasma_S01                     1.467878e-01
# Plasma_S02                     2.015139e-01
# Plasma_S04                     1.681739e-01
# Plasma_S06                     1.644356e-01
# Plasma_S03                     2.314392e-01
# Plasma_S05                     8.764960e-02
# Acinar_S01                     2.914640e-16
# Acinar_S03                     2.305894e-01
# Acinar_S04                     6.759656e-01
# Acinar_S02                     9.344499e-02
# NK_T_cell_CD8_T_cell_          2.007124e-01
# NK_T_cell_Treg                 1.499308e-01
# NK_T_cell_T_cell_Proliferating 2.551968e-01
# NK_T_cell_CD4_T_cell           2.498450e-01
# NK_T_cell_NK                   1.443151e-01
# NK_T_cell_CD8_T_cell_Exhausted 2.604632e-16
#                                TCGA.IB.AAUN.01A.12R.A38C.07
# Mast_S01                       1.057518e-01
# Mast_S02                       1.284870e-01
# Mast_S03                       2.681385e-01
# Mast_S05                       2.324775e-01
# Mast_S04                       2.651452e-01
# Stellate_S01                   6.582913e-02
# Stellate_S02                   4.788489e-01
# Stellate_S04                   6.820873e-02
# Stellate_S03                   5.919538e-08
# Stellate_S05                   3.871132e-01
# Fibroblast_myCAF               8.270162e-01
# Fibroblast_iCAF                1.729838e-01
# B_cell_S04                     2.572489e-01
# B_cell_S02                     2.353812e-01
# B_cell_S01                     4.688583e-01
# B_cell_S03                     3.851160e-02
# Malignant_Normal_Epithelial    1.979502e-02
# Malignant_Malignant_Cycling    5.049691e-01
# Malignant_Malignant_IC         1.746838e-01
# Malignant_Acinar               3.005521e-01
# Malignant_Malignant_Basal      3.124591e-16
# Malignant_Malignant_Classical  1.831880e-14
# Endothelial_S01                1.978284e-01
# Endothelial_S03                1.234729e-01
# Endothelial_S04                2.347235e-01
# Endothelial_S02                4.439751e-01
# Monocyte_DC_TAM_SPP1           1.145443e-01
# Monocyte_DC_DC                 1.846486e-01
# Monocyte_DC_DC_LAMP3           2.411509e-01
# Monocyte_DC_TAM_FCN1           3.621639e-01
# Monocyte_DC_pDC                9.749226e-02
# Monocyte_DC_TAM_C1QC           2.845975e-16
# Normal_Epithelial_S01          3.502434e-02
# Normal_Epithelial_S02          8.444275e-01
# Normal_Epithelial_S03          1.205482e-01
# Plasma_S01                     2.908149e-01
# Plasma_S02                     9.448136e-02
# Plasma_S04                     3.043123e-01
# Plasma_S06                     6.320901e-02
# Plasma_S03                     1.279064e-01
# Plasma_S05                     1.192761e-01
# Acinar_S01                     3.941400e-02
# Acinar_S03                     3.080035e-01
# Acinar_S04                     1.237047e-01
# Acinar_S02                     5.288778e-01
# NK_T_cell_CD8_T_cell_          4.181897e-01
# NK_T_cell_Treg                 1.844511e-01
# NK_T_cell_T_cell_Proliferating 2.483468e-16
# NK_T_cell_CD4_T_cell           1.492490e-01
# NK_T_cell_NK                   1.636031e-01
# NK_T_cell_CD8_T_cell_Exhausted 8.450712e-02
#                                TCGA.FB.AAPU.01A.31R.A41B.07
# Mast_S01                       1.051985e-01
# Mast_S02                       1.245972e-02
# Mast_S03                       4.370104e-01
# Mast_S05                       1.968673e-03
# Mast_S04                       4.433627e-01
# Stellate_S01                   1.552130e-02
# Stellate_S02                   1.228238e-01
# Stellate_S04                   8.861895e-03
# Stellate_S03                   1.353077e-16
# Stellate_S05                   8.527930e-01
# Fibroblast_myCAF               7.107278e-01
# Fibroblast_iCAF                2.892722e-01
# B_cell_S04                     6.153655e-01
# B_cell_S02                     6.958970e-02
# B_cell_S01                     3.150448e-01
# B_cell_S03                     5.588143e-13
# Malignant_Normal_Epithelial    2.241164e-03
# Malignant_Malignant_Cycling    1.424286e-01
# Malignant_Malignant_IC         1.554971e-16
# Malignant_Acinar               1.554971e-16
# Malignant_Malignant_Basal      1.317432e-03
# Malignant_Malignant_Classical  8.540128e-01
# Endothelial_S01                1.626540e-01
# Endothelial_S03                8.433842e-08
# Endothelial_S04                2.669312e-01
# Endothelial_S02                5.704147e-01
# Monocyte_DC_TAM_SPP1           6.243861e-02
# Monocyte_DC_DC                 2.455776e-01
# Monocyte_DC_DC_LAMP3           3.613754e-01
# Monocyte_DC_TAM_FCN1           2.404167e-01
# Monocyte_DC_pDC                9.019170e-02
# Monocyte_DC_TAM_C1QC           1.378832e-16
# Normal_Epithelial_S01          2.500737e-01
# Normal_Epithelial_S02          3.584721e-01
# Normal_Epithelial_S03          3.914543e-01
# Plasma_S01                     1.497875e-01
# Plasma_S02                     3.278500e-02
# Plasma_S04                     5.102907e-01
# Plasma_S06                     7.112436e-06
# Plasma_S03                     2.263367e-01
# Plasma_S05                     8.079293e-02
# Acinar_S01                     4.728282e-12
# Acinar_S03                     4.170668e-01
# Acinar_S04                     3.839987e-01
# Acinar_S02                     1.989345e-01
# NK_T_cell_CD8_T_cell_          6.929054e-01
# NK_T_cell_Treg                 6.701871e-02
# NK_T_cell_T_cell_Proliferating 1.393433e-16
# NK_T_cell_CD4_T_cell           2.206297e-01
# NK_T_cell_NK                   1.944622e-02
# NK_T_cell_CD8_T_cell_Exhausted 2.069592e-09
#                                TCGA.HZ.8001.01A.11R.2204.07
# Mast_S01                       1.868244e-01
# Mast_S02                       2.058607e-01
# Mast_S03                       1.271012e-01
# Mast_S05                       2.013660e-01
# Mast_S04                       2.788476e-01
# Stellate_S01                   3.554185e-01
# Stellate_S02                   6.117683e-02
# Stellate_S04                   4.654151e-01
# Stellate_S03                   7.945176e-02
# Stellate_S05                   3.853772e-02
# Fibroblast_myCAF               1.921491e-01
# Fibroblast_iCAF                8.078509e-01
# B_cell_S04                     2.554652e-01
# B_cell_S02                     6.526269e-01
# B_cell_S01                     4.199016e-02
# B_cell_S03                     4.991769e-02
# Malignant_Normal_Epithelial    6.311566e-01
# Malignant_Malignant_Cycling    2.605306e-16
# Malignant_Malignant_IC         2.086966e-01
# Malignant_Acinar               1.895862e-02
# Malignant_Malignant_Basal      1.411881e-01
# Malignant_Malignant_Classical  2.605306e-16
# Endothelial_S01                8.769188e-02
# Endothelial_S03                1.498246e-01
# Endothelial_S04                4.335919e-01
# Endothelial_S02                3.288917e-01
# Monocyte_DC_TAM_SPP1           4.823442e-02
# Monocyte_DC_DC                 1.914067e-01
# Monocyte_DC_DC_LAMP3           2.237495e-12
# Monocyte_DC_TAM_FCN1           2.614670e-01
# Monocyte_DC_pDC                2.216731e-16
# Monocyte_DC_TAM_C1QC           4.988919e-01
# Normal_Epithelial_S01          8.293045e-01
# Normal_Epithelial_S02          1.008260e-03
# Normal_Epithelial_S03          1.696872e-01
# Plasma_S01                     3.522434e-01
# Plasma_S02                     1.198739e-01
# Plasma_S04                     6.403066e-15
# Plasma_S06                     2.301656e-01
# Plasma_S03                     1.544611e-02
# Plasma_S05                     2.822710e-01
# Acinar_S01                     6.846751e-02
# Acinar_S03                     9.347520e-02
# Acinar_S04                     4.269302e-01
# Acinar_S02                     4.111271e-01
# NK_T_cell_CD8_T_cell_          1.446768e-01
# NK_T_cell_Treg                 1.581593e-01
# NK_T_cell_T_cell_Proliferating 1.671513e-01
# NK_T_cell_CD4_T_cell           2.388135e-01
# NK_T_cell_NK                   2.083864e-01
# NK_T_cell_CD8_T_cell_Exhausted 8.281272e-02
#                                TCGA.IB.7651.01A.11R.2156.07
# Mast_S01                       1.881198e-01
# Mast_S02                       2.355800e-01
# Mast_S03                       1.480721e-01
# Mast_S05                       1.818730e-01
# Mast_S04                       2.463551e-01
# Stellate_S01                   5.700050e-03
# Stellate_S02                   5.201547e-01
# Stellate_S04                   2.059963e-01
# Stellate_S03                   1.054595e-01
# Stellate_S05                   1.626894e-01
# Fibroblast_myCAF               4.374929e-01
# Fibroblast_iCAF                5.625071e-01
# B_cell_S04                     3.470904e-01
# B_cell_S02                     5.609913e-01
# B_cell_S01                     9.191831e-02
# B_cell_S03                     5.073562e-08
# Malignant_Normal_Epithelial    4.373039e-02
# Malignant_Malignant_Cycling    1.056209e-01
# Malignant_Malignant_IC         1.839677e-01
# Malignant_Acinar               2.963219e-01
# Malignant_Malignant_Basal      2.323005e-02
# Malignant_Malignant_Classical  3.471291e-01
# Endothelial_S01                1.128890e-01
# Endothelial_S03                1.276806e-01
# Endothelial_S04                2.591141e-01
# Endothelial_S02                5.003163e-01
# Monocyte_DC_TAM_SPP1           3.624097e-09
# Monocyte_DC_DC                 2.298772e-03
# Monocyte_DC_DC_LAMP3           1.296677e-02
# Monocyte_DC_TAM_FCN1           8.853333e-02
# Monocyte_DC_pDC                2.906254e-05
# Monocyte_DC_TAM_C1QC           8.961721e-01
# Normal_Epithelial_S01          2.474155e-16
# Normal_Epithelial_S02          7.829737e-01
# Normal_Epithelial_S03          2.170263e-01
# Plasma_S01                     1.565934e-02
# Plasma_S02                     2.884550e-01
# Plasma_S04                     5.896557e-02
# Plasma_S06                     1.855500e-01
# Plasma_S03                     2.707488e-01
# Plasma_S05                     1.806214e-01
# Acinar_S01                     6.017905e-02
# Acinar_S03                     4.701329e-01
# Acinar_S04                     9.957762e-02
# Acinar_S02                     3.701104e-01
# NK_T_cell_CD8_T_cell_          7.935215e-09
# NK_T_cell_Treg                 1.764385e-01
# NK_T_cell_T_cell_Proliferating 1.579632e-09
# NK_T_cell_CD4_T_cell           1.161591e-01
# NK_T_cell_NK                   3.009611e-01
# NK_T_cell_CD8_T_cell_Exhausted 4.064412e-01

# %%
all_H = all_H[match(ecotypes$ID, rownames(all_H)),]
write.table(all_H, file.path(output_dir, "combined_state_abundances.txt"), sep = "\t")

# %%
all_H
# Out:
#       X  XT18 XT16 XN2 XT19 XT7 XT8 XT11 XT21 XT22 ⋯ XT14 XN11 XT12 XT15 XT5
# NA    NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.1  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.2  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.3  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.4  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.5  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.6  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.7  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.8  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.9  NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.10 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.11 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.12 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.13 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.14 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.15 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.16 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.17 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.18 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.19 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.20 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.21 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.22 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
# NA.23 NA NA   NA   NA  NA   NA  NA  NA   NA   NA   ⋯ NA   NA   NA   NA   NA
#       XT4 XN9 XN3 XT1 XT10
# NA    NA  NA  NA  NA  NA
# NA.1  NA  NA  NA  NA  NA
# NA.2  NA  NA  NA  NA  NA
# NA.3  NA  NA  NA  NA  NA
# NA.4  NA  NA  NA  NA  NA
# NA.5  NA  NA  NA  NA  NA
# NA.6  NA  NA  NA  NA  NA
# NA.7  NA  NA  NA  NA  NA
# NA.8  NA  NA  NA  NA  NA
# NA.9  NA  NA  NA  NA  NA
# NA.10 NA  NA  NA  NA  NA
# NA.11 NA  NA  NA  NA  NA
# NA.12 NA  NA  NA  NA  NA
# NA.13 NA  NA  NA  NA  NA
# NA.14 NA  NA  NA  NA  NA
# NA.15 NA  NA  NA  NA  NA
# NA.16 NA  NA  NA  NA  NA
# NA.17 NA  NA  NA  NA  NA
# NA.18 NA  NA  NA  NA  NA
# NA.19 NA  NA  NA  NA  NA
# NA.20 NA  NA  NA  NA  NA
# NA.21 NA  NA  NA  NA  NA
# NA.22 NA  NA  NA  NA  NA
# NA.23 NA  NA  NA  NA  NA

# %%
H = do.call(rbind, lapply(levels(ecotypes$Ecotype), function(clst){
	clst <<- clst
	#print(clst)
	inc <<- ecotypes[ecotypes$Ecotype == clst,]$ID
	apply(all_H[rownames(all_H) %in% inc,,drop = F], 2, mean)
}))
rownames(H) = levels(ecotypes$Ecotype)
#write.table(H, file.path(output_dir, "ecotype_abundance.txt"), sep = "\t")
H = apply(H, 2, function(x) x / sum(x))
write.table(H, file.path(output_dir, "ecotype_abundance.txt"), sep = "\t")

p_vals = do.call(rbind, lapply(levels(ecotypes$Ecotype), function(clst){
	clst <<- clst
	#print(clst)
	inc <<- ecotypes[ecotypes$Ecotype == clst,]$ID
	
	apply(all_H, 2, function(x){
		x <<- x
		err <<- F
		p <<- 1
		tryCatch({
			p <<- t.test(x[rownames(all_H) %in% inc], x[!(rownames(all_H) %in% inc)])$p.value
		}, error = function(x) err <<- T)
		p
	})
	
})) 
rownames(p_vals) = levels(ecotypes$Ecotype)
write.table(p_vals, file.path(output_dir, "assignment_p_vals.txt"), sep = "\t")

assignment = as.data.frame(apply(H, 2, function(x) rownames(H)[which.max(x)]))

clinical = data.frame(ID = rownames(assignment), MaxEcotype = assignment[,1])
clinical$AssignmentP = sapply(1:ncol(H), function(i) {
	p_vals[which.max(H[,i]), i] 
	})
clinical$AssignmentQ = p.adjust(clinical$AssignmentP, method = "BH")

clinical$AssignedToEcotypeStates = clinical$ID %in% all_classes_filt$ID
clinical$Ecotype = ifelse((clinical$AssignmentQ < 0.25) & clinical$AssignedToEcotypeStates, as.character(clinical$MaxEcotype), "Unassigned")
clinical$Ecotype = factor(as.character(clinical$Ecotype), levels = c(levels(ecotypes$Ecotype), "Unassigned"))

# tmp = read_clinical(clinical$ID, dataset = test_dataset, dataset_type = "bulk")
tmp = read_clinical_bulk(clinical$ID, bulkInputDir = inputDir, dataset_type = "bulk")                                 

to_rem = colnames(tmp)[colnames(tmp) %in% colnames(clinical)]
to_rem = to_rem[to_rem != "ID"]
tmp = tmp[,!colnames(tmp) %in% to_rem, drop = F]
clinical = merge(clinical, tmp, by = "ID", all.x = T)

clinical = clinical[order(clinical$Ecotype),]

H = H[,match(clinical$ID, colnames(H))]
all_H = all_H[,match(clinical$ID, colnames(all_H))]
all_H = all_H[match(ecotypes$ID, rownames(all_H)),]

write.table(clinical, file.path(output_dir, "initial_ecotype_assignment.txt"), sep = "\t")

rownames(clinical) = clinical$ID
rownames(ecotypes) = ecotypes$ID

clinical_filt = clinical[clinical$Ecotype != "Unassigned",]
clinical_filt$Ecotype = factor(as.character(clinical_filt$Ecotype), levels = levels(ecotypes$Ecotype))
write.table(clinical_filt, file.path(output_dir, "ecotype_assignment.txt"), sep = "\t")

h <- heatmap_simple(all_H, top_annotation = clinical_filt, top_columns = top_cols, 
	left_annotation = ecotypes, left_columns = c("Ecotype", "CellType", "State"),
	column_split = ifelse(clinical$Ecotype == "Unassigned", "Unassigned", "Assigned"),
	width = unit(7, "in"), height = unit(4, "in"),
	legend_name = "State abundance",
	color_range = seq(0, quantile(as.matrix(all_H), .9), length.out = 8), color_palette = c("white", viridis(8)), raster_quality = 5)

pdf(file.path(output_dir, "heatmap_all_samples.pdf"), width = 12, height = 7)
draw(h, heatmap_legend_side = "bottom", annotation_legend_side = "bottom", merge_legends = T)	
tmp = dev.off()

small_H = as.matrix(all_H[,match(clinical_filt$ID, colnames(all_H))])

if(is.null(small_H) || nrow(small_H) == 0 || ncol(small_H) == 0)
{
	stop(paste("No samples were assigned to ecotypes!"))
}

h = heatmap_simple(small_H, top_annotation = clinical_filt, top_columns = top_cols, 
	left_annotation = ecotypes, left_columns = c("Ecotype", "CellType", "State"),
	width = unit(5, "in"), height = unit(3, "in"),
	legend_name = "State abundance",
	color_range = seq(0, quantile(as.matrix(all_H), .9), length.out = 8), color_palette = c("white", viridis(8)), raster_quality = 20)

pdf(file.path(output_dir, "heatmap_assigned_samples_viridis.pdf"), width = 8, height = 7)
draw(h, heatmap_legend_side = "bottom", annotation_legend_side = "bottom", merge_legends = T)	
#draw(h1, heatmap_legend_side = "bottom", annotation_legend_side = "bottom", merge_legends = T)	
suppressWarnings({
rect = rectangle_annotation_coordinates(ecotypes$Ecotype, clinical_filt$Ecotype)
})
decorate_heatmap_body("hmap", {
    grid.rect(x = unit(rect$x, "native"), y = unit(rect$y, "native"), width = unit(rect$w, "native"), height = unit(rect$h, "native"), hjust = 0, vjust = 1, gp = gpar(col = "white", fill = NA, lty = 1, lwd = 3))
})
tmp = dev.off()

png(file.path(output_dir, "heatmap_assigned_samples_viridis.png"), width = 8, height = 7, units = "in", res = 300)
draw(h, heatmap_legend_side = "bottom", annotation_legend_side = "bottom", merge_legends = T)	
decorate_heatmap_body("hmap", {
    grid.rect(x = unit(rect$x, "native"), y = unit(rect$y, "native"), width = unit(rect$w, "native"), height = unit(rect$h, "native"), hjust = 0, vjust = 1, gp = gpar(col = "white", fill = NA, lty = 1, lwd = 3))
})
tmp = dev.off()

h = heatmap_simple(small_H, top_annotation = clinical, top_columns = top_cols, 
	left_annotation = ecotypes, left_columns = c("Ecotype", "CellType", "State"),
	width = unit(5, "in"), height = unit(3, "in"), 
	legend_name = "State abundance",
	color_range = c(seq(0, quantile(small_H, .8), length.out = 8)), color_palette = c("black", brewer.pal(8, "YlGnBu")), raster_quality = 20)

pdf(file.path(output_dir, "heatmap_assigned_samples_YlGnBu.pdf"), width = 8, height = 7)
draw(h, heatmap_legend_side = "bottom", annotation_legend_side = "bottom", merge_legends = T)	
decorate_heatmap_body("hmap", {
    grid.rect(x = unit(rect$x, "native"), y = unit(rect$y, "native"), width = unit(rect$w, "native"), height = unit(rect$h, "native"), hjust = 0, vjust = 1, gp = gpar(col = "white", fill = NA, lty = 1, lwd = 3))
})
tmp = dev.off()

png(file.path(output_dir, "heatmap_assigned_samples_YlGnBu.png"), width = 8, height = 7, units = "in", res = 300)
draw(h, heatmap_legend_side = "bottom", annotation_legend_side = "bottom", merge_legends = T)	
decorate_heatmap_body("hmap", {
    grid.rect(x = unit(rect$x, "native"), y = unit(rect$y, "native"), width = unit(rect$w, "native"), height = unit(rect$h, "native"), hjust = 0, vjust = 1, gp = gpar(col = "white", fill = NA, lty = 1, lwd = 3))
})
tmp = dev.off()

# %%
keyDir = "Test_12_Complete_Peng_Discovered_States_Ecotype_Discovery_PDSM_Updated_Recovery_SSM_Run_090222"
bulkInputsDir = "Test_12_Complete_Peng_Discovered_States_Ecotype_Discovery_PDSM_Updated_Recovery_SSM_Run_090222/TCGA_Recovery_090222/Inputs"
outputDir = "Test_12_Complete_Peng_Discovered_States_Ecotype_Discovery_PDSM_Updated_Recovery_SSM_Run_090222"
n_threads = 8

# %%
PushToJobQueue((paste("Rscript /duo4/users/pchati/EcoTyper_Updated/ecotyper/pipeline_PDSM/ecotypes_recovery_PDSM_Updated.R", keyDir, bulkInputsDir, outputDir))) 

RunJobQueue()
# Out:
# Error in RunJobQueue(): EcoTyper failed. Please check the error message above!
# Traceback:
#
# 1. RunJobQueue()
# 2. stop("EcoTyper failed. Please check the error message above!")
